# %%
Menampilkan Citra

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("D:\EDIT\hello future.jfif")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.title('Original Image')
plt.imshow(image)

# %%
Menampilkan Informasi Resolusi

# %%
m = image.shape[0]
n = image.shape[1]

# %%
print(str(m)+ "x" + str(n))
# Out:
# 640x640

# %%
Menampilkan Tingkat Keabuan

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(cv2.cvtColor(gray_image, cv2.COLOR_GRAY2RGB))

# %%
print(gray_image)
# Out:
# [[229 229 229 ... 229 229 229]
#  [229 229 229 ... 229 229 229]
#  [229 229 229 ... 229 229 229]
#  ...
#  [229 229 229 ... 229 229 229]
#  [229 229 229 ... 229 229 229]
#  [229 229 229 ... 229 229 229]]

# %%
np.unique(gray_image[0])
# Out:
# array([229], dtype=uint8)
