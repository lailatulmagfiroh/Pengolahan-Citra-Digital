# %%
# Average Method

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from skimage import data
image = cv2.imread("D:\Fotokuu\Photograph\IMG_20200126_174905_1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-19ccbae1dde3> in <module>
#       1 from skimage import data
# ----> 2 image = cv2.imread("D:\Fotokuu\Photograph\IMG_20200126_174905_1.jpg")
#       3 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(image)
#
# NameError: name 'cv2' is not defined

# %%
x,y,z=image.shape

# %%
# Gray = (R + G + B) / 3 
image [:] = image.mean(axis=-1,keepdims=1)

# %%
plt.figure(figsize=(10,20))
plt.imshow(image)
